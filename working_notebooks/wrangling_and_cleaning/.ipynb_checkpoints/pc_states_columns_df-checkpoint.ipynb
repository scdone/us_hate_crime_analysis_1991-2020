# %%
import pandas as pd

# %%
df_2000 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2000.csv")
df_2001 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2001.csv")
df_2002 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2002.csv")
df_2003 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2003.csv")
df_2004 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2004.csv")
df_2005 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2005.csv")
df_2006 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2006.csv")
df_2007 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2007.csv")
df_2008 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2008.csv")
df_2009 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2009.csv")
df_2010 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2010.csv")
df_2011 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2011.csv")
df_2012 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2012.csv")
df_2013 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2013.csv")
df_2014 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2014.csv")
df_2015 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2015.csv")
df_2016 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2016.csv")
df_2017 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2017.csv")
df_2018 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2018.csv")
df_2019 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2019.csv")
df_2020 = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_2020.csv")

# %%
state_list = df_2000.state.tolist()

# %%
transposed_2000 = df_2000[['state','total_incidents_per_capita']].transpose()
transposed_2000.rename(index={'total_incidents_per_capita':'2000'}, inplace=True)
transposed_2000.columns = state_list
transposed_2000.drop(index=['state'], inplace=True)

# %%
transposed_2001 = df_2001[['state','total_incidents_per_capita']].transpose()
transposed_2001.rename(index={'total_incidents_per_capita':'2001'}, inplace=True)
transposed_2001.columns = state_list
transposed_2001.drop(index=['state'], inplace=True)

# %%
transposed_2002 = df_2002[['state','total_incidents_per_capita']].transpose()
transposed_2002.rename(index={'total_incidents_per_capita':'2002'}, inplace=True)
transposed_2002.columns = state_list
transposed_2002.drop(index=['state'], inplace=True)

# %%
transposed_2003 = df_2003[['state','total_incidents_per_capita']].transpose()
transposed_2003.rename(index={'total_incidents_per_capita':'2003'}, inplace=True)
transposed_2003.columns = state_list
transposed_2003.drop(index=['state'], inplace=True)

# %%
transposed_2004 = df_2004[['state','total_incidents_per_capita']].transpose()
transposed_2004.rename(index={'total_incidents_per_capita':'2004'}, inplace=True)
transposed_2004.columns = state_list
transposed_2004.drop(index=['state'], inplace=True)

# %%
transposed_2005 = df_2005[['state','total_incidents_per_capita']].transpose()
transposed_2005.rename(index={'total_incidents_per_capita':'2005'}, inplace=True)
transposed_2005.columns = state_list
transposed_2005.drop(index=['state'], inplace=True)

# %%
transposed_2006 = df_2006[['state','total_incidents_per_capita']].transpose()
transposed_2006.rename(index={'total_incidents_per_capita':'2006'}, inplace=True)
transposed_2006.columns = state_list
transposed_2006.drop(index=['state'], inplace=True)

# %%
transposed_2007 = df_2007[['state','total_incidents_per_capita']].transpose()
transposed_2007.rename(index={'total_incidents_per_capita':'2007'}, inplace=True)
transposed_2007.columns = state_list
transposed_2007.drop(index=['state'], inplace=True)

# %%
transposed_2008 = df_2008[['state','total_incidents_per_capita']].transpose()
transposed_2008.rename(index={'total_incidents_per_capita':'2008'}, inplace=True)
transposed_2008.columns = state_list
transposed_2008.drop(index=['state'], inplace=True)

# %%
transposed_2009 = df_2009[['state','total_incidents_per_capita']].transpose()
transposed_2009.rename(index={'total_incidents_per_capita':'2009'}, inplace=True)
transposed_2009.columns = state_list
transposed_2009.drop(index=['state'], inplace=True)

# %%
transposed_2010 = df_2010[['state','total_incidents_per_capita']].transpose()
transposed_2010.rename(index={'total_incidents_per_capita':'2010'}, inplace=True)
transposed_2010.columns = state_list
transposed_2010.drop(index=['state'], inplace=True)

# %%
transposed_2011 = df_2011[['state','total_incidents_per_capita']].transpose()
transposed_2011.rename(index={'total_incidents_per_capita':'2011'}, inplace=True)
transposed_2011.columns = state_list
transposed_2011.drop(index=['state'], inplace=True)

# %%
transposed_2012 = df_2012[['state','total_incidents_per_capita']].transpose()
transposed_2012.rename(index={'total_incidents_per_capita':'2012'}, inplace=True)
transposed_2012.columns = state_list
transposed_2012.drop(index=['state'], inplace=True)

# %%
transposed_2013 = df_2013[['state','total_incidents_per_capita']].transpose()
transposed_2013.rename(index={'total_incidents_per_capita':'2013'}, inplace=True)
transposed_2013.columns = state_list
transposed_2013.drop(index=['state'], inplace=True)

# %%
transposed_2014 = df_2014[['state','total_incidents_per_capita']].transpose()
transposed_2014.rename(index={'total_incidents_per_capita':'2014'}, inplace=True)
transposed_2014.columns = state_list
transposed_2014.drop(index=['state'], inplace=True)

# %%
transposed_2015 = df_2015[['state','total_incidents_per_capita']].transpose()
transposed_2015.rename(index={'total_incidents_per_capita':'2015'}, inplace=True)
transposed_2015.columns = state_list
transposed_2015.drop(index=['state'], inplace=True)

# %%
transposed_2016 = df_2016[['state','total_incidents_per_capita']].transpose()
transposed_2016.rename(index={'total_incidents_per_capita':'2016'}, inplace=True)
transposed_2016.columns = state_list
transposed_2016.drop(index=['state'], inplace=True)

# %%
transposed_2017 = df_2017[['state','total_incidents_per_capita']].transpose()
transposed_2017.rename(index={'total_incidents_per_capita':'2017'}, inplace=True)
transposed_2017.columns = state_list
transposed_2017.drop(index=['state'], inplace=True)

# %%
transposed_2018 = df_2018[['state','total_incidents_per_capita']].transpose()
transposed_2018.rename(index={'total_incidents_per_capita':'2018'}, inplace=True)
transposed_2018.columns = state_list
transposed_2018.drop(index=['state'], inplace=True)

# %%
transposed_2019 = df_2019[['state','total_incidents_per_capita']].transpose()
transposed_2019.rename(index={'total_incidents_per_capita':'2019'}, inplace=True)
transposed_2019.columns = state_list
transposed_2019.drop(index=['state'], inplace=True)

# %%
transposed_2020 = df_2020[['state','total_incidents_per_capita']].transpose()
transposed_2020.rename(index={'total_incidents_per_capita':'2020'}, inplace=True)
transposed_2020.columns = state_list
transposed_2020.drop(index=['state'], inplace=True)

# %%
merged_df = transposed_2000.append(transposed_2001)

# %%
merged_df = merged_df.append(transposed_2002)

# %%
merged_df = merged_df.append(transposed_2003)

# %%
merged_df = merged_df.append(transposed_2004)

# %%
merged_df = merged_df.append(transposed_2005)

# %%
merged_df = merged_df.append(transposed_2006)

# %%
merged_df = merged_df.append(transposed_2007)

# %%
merged_df = merged_df.append(transposed_2008)

# %%
merged_df = merged_df.append(transposed_2009)

# %%
merged_df = merged_df.append(transposed_2010)

# %%
merged_df = merged_df.append(transposed_2011)

# %%
merged_df = merged_df.append(transposed_2012)

# %%
merged_df = merged_df.append(transposed_2013)

# %%
merged_df = merged_df.append(transposed_2014)

# %%
merged_df = merged_df.append(transposed_2015)

# %%
merged_df = merged_df.append(transposed_2016)

# %%
merged_df = merged_df.append(transposed_2017)

# %%
merged_df = merged_df.append(transposed_2018)

# %%
merged_df = merged_df.append(transposed_2019)

# %%
merged_df = merged_df.append(transposed_2020)

# %%
merged_df
# Out:
#        Alabama    Alaska   Arizona  Arkansas California  Colorado Connecticut  \
# 2000  0.044922   0.63698  5.445118  0.111999   5.716727  2.334223    4.572397
# 2001  0.044766  3.155998  7.319649  0.111459   6.514024  2.847016    4.981306
# 2002  0.044642  1.089771   4.46606  6.393373   4.725876  2.137891    4.047706
# 2003  0.022205  2.004892  4.482463  6.349053   4.175512  1.898986    4.218881
# 2004  0.066215  1.365113  3.980607  3.018526   3.915718  1.311472    3.432402
# 2005  0.722131  0.599749  3.322443    4.8542   3.851742  2.698684     2.93702
# 2006    0.7129  0.888491  2.803053  4.004591   3.600657  2.965836     3.61056
# 2007  0.149802  1.175952  2.610381  1.158443   3.862036  3.289016    4.082477
# 2008  0.233139  1.163713   2.94569  3.200496   3.775509  3.353968    5.048541
# 2009  0.189158  1.287747  3.452541  2.589025   2.754237  4.183263    5.615127
# 2010  0.397032  0.980417  3.683275  2.190282    2.92608  3.050992    4.107094
# ...

# %%
merged_df.reset_index(inplace=True)

# %%
merged_df.rename(columns={'index':'year'}, inplace=True)
# Out:
#    index   Alabama    Alaska   Arizona  Arkansas California  Colorado  \
# 0   2000  0.044922   0.63698  5.445118  0.111999   5.716727  2.334223
# 1   2001  0.044766  3.155998  7.319649  0.111459   6.514024  2.847016
# 2   2002  0.044642  1.089771   4.46606  6.393373   4.725876  2.137891
# 3   2003  0.022205  2.004892  4.482463  6.349053   4.175512  1.898986
# 4   2004  0.066215  1.365113  3.980607  3.018526   3.915718  1.311472
# 5   2005  0.722131  0.599749  3.322443    4.8542   3.851742  2.698684
# 6   2006    0.7129  0.888491  2.803053  4.004591   3.600657  2.965836
# 7   2007  0.149802  1.175952  2.610381  1.158443   3.862036  3.289016
# 8   2008  0.233139  1.163713   2.94569  3.200496   3.775509  3.353968
# 9   2009  0.189158  1.287747  3.452541  2.589025   2.754237  4.183263
# 10  2010  0.397032  0.980417  3.683275  2.190282    2.92608  3.050992
# 11  2011  1.729296  1.107498  2.981424  1.224058   2.763289  3.631465
# ...

# %%
merged_df.to_csv('state_totals_by_year.csv', index=False)

# %%
us_df = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\us_pop_totals.csv")

# %%
us_df = us_df[us_df.year >= 2000].copy()

# %%
us_df.reset_index(inplace=True)

# %%
us_df.drop(columns=['index'], inplace=True)

# %%
us_df
# Out:
#              area  year  pop_estimate
# 0   United States  2000     282162411
# 1   United States  2001     284968955
# 2   United States  2002     287625193
# 3   United States  2003     290107933
# 4   United States  2004     292805298
# 5   United States  2005     295516599
# 6   United States  2006     298379912
# 7   United States  2007     301231207
# 8   United States  2008     304093966
# 9   United States  2009     306771529
# 10  United States  2010     309327143
# 11  United States  2011     311583481
# 12  United States  2012     313877662
# 13  United States  2013     316059947
# 14  United States  2014     318386329
# 15  United States  2015     320738994
# 16  United States  2016     323071755
# 17  United States  2017     325122128
# 18  United States  2018     326838199
# 19  United States  2019     328329953
# 20  United States  2020     331501080

# %%
state_totals_df = pd.read_csv(r"C:\Users\14802\Desktop\hate-crime analysis\datasets\per_capita_master.csv")

# %%
state_totals_df = state_totals_df[state_totals_df.year >= 2000].copy()

# %%
state_totals_df = state_totals_df[['year','total_incidents']].copy()

# %%
year_totals_df = state_totals_df.groupby('year').sum()

# %%
year_totals_df.reset_index(inplace=True)

# %%
year_totals_df.drop(columns=['index'], inplace=True)

# %%
year_totals_df
# Out:
#     year  total_incidents
# 0   2000           8219.0
# 1   2001           9730.0
# 2   2002           7485.0
# 3   2003           7545.0
# 4   2004           7685.0
# 5   2005           7411.0
# 6   2006           7711.0
# 7   2007           7625.0
# 8   2008           8039.0
# 9   2009           6613.0
# 10  2010           6633.0
# 11  2011           6299.0
# 12  2012           6594.0
# 13  2013           6044.0
# 14  2014           5599.0
# 15  2015           5870.0
# 16  2016           6276.0
# 17  2017           7318.0
# 18  2018           7088.0
# 19  2019           7768.0
# 20  2020          10083.0

# %%
us_df = us_df.merge(year_totals_df, on='year')

# %%
us_df
# Out:
#              area  year  pop_estimate  total_incidents
# 0   United States  2000     282162411           8219.0
# 1   United States  2001     284968955           9730.0
# 2   United States  2002     287625193           7485.0
# 3   United States  2003     290107933           7545.0
# 4   United States  2004     292805298           7685.0
# 5   United States  2005     295516599           7411.0
# 6   United States  2006     298379912           7711.0
# 7   United States  2007     301231207           7625.0
# 8   United States  2008     304093966           8039.0
# 9   United States  2009     306771529           6613.0
# 10  United States  2010     309327143           6633.0
# 11  United States  2011     311583481           6299.0
# 12  United States  2012     313877662           6594.0
# 13  United States  2013     316059947           6044.0
# 14  United States  2014     318386329           5599.0
# 15  United States  2015     320738994           5870.0
# ...

# %%
per_capita = us_df.copy() # makes copy of clean dataframe to start adding per capita values

pop_list = per_capita.pop_estimate.tolist() # sets population estimates to list 

total_incidents_list = per_capita.total_incidents.tolist() # sets total incidents to list

# %%
# function to find per capita incidents

per_capita_list = []

def per_capita_totals():
    for pop, total in zip(pop_list, total_incidents_list):

        per_capita_list.append((total/pop)*100000)

# %%
per_capita_totals()

# %%
per_capita_list
# Out:
# [2.9128614158318915,
#  3.414407018476802,
#  2.6023450595303035,
#  2.6007561813209708,
#  2.6246109795458685,
#  2.507811752394998,
#  2.5842892533596564,
#  2.5312782416995727,
#  2.643590764310003,
#  2.1556759264970773,
#  2.1443317051552766,
#  2.0216090980766723,
#  2.100818502974576,
#  1.9122954545075588,
#  1.7585554058132942,
#  1.8301485350421722,
#  1.9426025032736147,
#  2.2508464880618644,
#  2.1686571587062256,
#  2.365912682964993,
#  3.041619049928887]

# %%
us_df.insert(4, 'total_incidents_per_capita', per_capita_list)

# %%
us_df
# Out:
#              area  year  pop_estimate  total_incidents  \
# 0   United States  2000     282162411           8219.0
# 1   United States  2001     284968955           9730.0
# 2   United States  2002     287625193           7485.0
# 3   United States  2003     290107933           7545.0
# 4   United States  2004     292805298           7685.0
# 5   United States  2005     295516599           7411.0
# 6   United States  2006     298379912           7711.0
# 7   United States  2007     301231207           7625.0
# 8   United States  2008     304093966           8039.0
# 9   United States  2009     306771529           6613.0
# 10  United States  2010     309327143           6633.0
# 11  United States  2011     311583481           6299.0
# 12  United States  2012     313877662           6594.0
# 13  United States  2013     316059947           6044.0
# 14  United States  2014     318386329           5599.0
# 15  United States  2015     320738994           5870.0
# ...

# %%
us_df.to_csv('us_per_cap_totals.csv', index=False)

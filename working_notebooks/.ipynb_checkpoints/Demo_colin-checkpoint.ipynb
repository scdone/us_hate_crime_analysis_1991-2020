# %%
import pandas as pd

pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv(r"C:\Users\14802\Desktop\DATA_PROJECTS\Match.csv")

# %%
df
# Out:
#       match_id  country_id  league_id     season  stage             date  \
# 0            1           1          1  2008/2009      1   8/17/2008 0:00
# 1            2           1          1  2008/2009      1   8/16/2008 0:00
# 2            3           1          1  2008/2009      1   8/16/2008 0:00
# 3            4           1          1  2008/2009      1   8/17/2008 0:00
# 4            5           1          1  2008/2009      1   8/16/2008 0:00
# 5            6           1          1  2008/2009      1   9/24/2008 0:00
# 6            7           1          1  2008/2009      1   8/16/2008 0:00
# 7            8           1          1  2008/2009      1   8/16/2008 0:00
# 8            9           1          1  2008/2009      1   8/16/2008 0:00
# 9           10           1          1  2008/2009     10   11/1/2008 0:00
# 10          11           1          1  2008/2009     10  10/31/2008 0:00
# 11          12           1          1  2008/2009     10   11/2/2008 0:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Columns: 115 entries, match_id to BSA
# dtypes: float64(104), int64(9), object(2)
# memory usage: 1.5+ MB

# %%
df.columns.tolist()
# Out:
# ['match_id',
#  'country_id',
#  'league_id',
#  'season',
#  'stage',
#  'date',
#  'match_api_id',
#  'home_team_api_id',
#  'away_team_api_id',
#  'home_team_goal',
#  'away_team_goal',
#  'home_player_X1',
#  'home_player_X2',
#  'home_player_X3',
#  'home_player_X4',
#  'home_player_X5',
#  'home_player_X6',
#  'home_player_X7',
#  'home_player_X8',
#  'home_player_X9',
#  'home_player_X10',
#  'home_player_X11',
#  'away_player_X1',
#  'away_player_X2',
#  'away_player_X3',
#  'away_player_X4',
#  'away_player_X5',
#  'away_player_X6',
#  'away_player_X7',
#  'away_player_X8',
#  'away_player_X9',
#  'away_player_X10',
#  'away_player_X11',
#  'home_player_Y1',
#  'home_player_Y2',
#  'home_player_Y3',
#  'home_player_Y4',
#  'home_player_Y5',
#  'home_player_Y6',
#  'home_player_Y7',
#  'home_player_Y8',
#  'home_player_Y9',
#  'home_player_Y10',
#  'home_player_Y11',
#  'away_player_Y1',
#  'away_player_Y2',
#  'away_player_Y3',
#  'away_player_Y4',
#  'away_player_Y5',
# ...

# %%
df_clean = df[['match_id',
 'country_id',
 'league_id',
 'season',
 'stage',
 'date',
 'match_api_id',
 'home_team_api_id',
 'away_team_api_id',
]].copy()

# %%
df_clean
# Out:
#       match_id  country_id  league_id     season  stage             date  \
# 0            1           1          1  2008/2009      1   8/17/2008 0:00
# 1            2           1          1  2008/2009      1   8/16/2008 0:00
# 2            3           1          1  2008/2009      1   8/16/2008 0:00
# 3            4           1          1  2008/2009      1   8/17/2008 0:00
# 4            5           1          1  2008/2009      1   8/16/2008 0:00
# 5            6           1          1  2008/2009      1   9/24/2008 0:00
# 6            7           1          1  2008/2009      1   8/16/2008 0:00
# 7            8           1          1  2008/2009      1   8/16/2008 0:00
# 8            9           1          1  2008/2009      1   8/16/2008 0:00
# 9           10           1          1  2008/2009     10   11/1/2008 0:00
# 10          11           1          1  2008/2009     10  10/31/2008 0:00
# 11          12           1          1  2008/2009     10   11/2/2008 0:00
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          1728 non-null   int64
#  1   country_id        1728 non-null   int64
#  2   league_id         1728 non-null   int64
#  3   season            1728 non-null   object
#  4   stage             1728 non-null   int64
#  5   date              1728 non-null   object
#  6   match_api_id      1728 non-null   int64
#  7   home_team_api_id  1728 non-null   int64
#  8   away_team_api_id  1728 non-null   int64
#  9   home_team_goal    1728 non-null   int64
#  10  away_team_goal    1728 non-null   int64
#  11  goal              0 non-null      float64
#  12  shoton            0 non-null      float64
#  13  shotoff           0 non-null      float64
#  14  foulcommit        0 non-null      float64
#  15  card              0 non-null      float64
# ...

# %%
df_clean.to_csv('clean_match.csv', index=False)

# %%
df_clean.query('season == "2008/2009"')
# Out:
#      match_id  country_id  league_id     season  stage             date  \
# 0           1           1          1  2008/2009      1   8/17/2008 0:00
# 1           2           1          1  2008/2009      1   8/16/2008 0:00
# 2           3           1          1  2008/2009      1   8/16/2008 0:00
# 3           4           1          1  2008/2009      1   8/17/2008 0:00
# 4           5           1          1  2008/2009      1   8/16/2008 0:00
# 5           6           1          1  2008/2009      1   9/24/2008 0:00
# 6           7           1          1  2008/2009      1   8/16/2008 0:00
# 7           8           1          1  2008/2009      1   8/16/2008 0:00
# 8           9           1          1  2008/2009      1   8/16/2008 0:00
# 9          10           1          1  2008/2009     10   11/1/2008 0:00
# 10         11           1          1  2008/2009     10  10/31/2008 0:00
# 11         12           1          1  2008/2009     10   11/2/2008 0:00
# ...
